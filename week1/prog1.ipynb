# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4536/pythonprograms/blob/main/week1/prog1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World\npython" )
# Out:
# Hello World
# python

# %%
#this code is belongs to some arthimetic operations
x=int(input("Enter a value "))
y=int(input("Enter a another "))
print(x+y,"is the sum of two numbers")
print(x//y,"is the floor division two numbers")
print(x**y,"it is the exponentiaonal")
print(x-y,"is the subtraction of two numbers")
print(x%y,"it is the moduluos operation between two numbers")
print(x/y,"the division of two numbers")
# Out:
# Enter a value 2
# Enter a another 4
# 6 is the sum of two numbers
# 0 is the floor division two numbers
# 16 it is the exponentiaonal
# -2 is the subtraction of two numbers
# 2 it is the moduluos operation between two numbers
# 0.5 the division of two numbers

# %%
#this code belongs to conditional operators
a=int(input("enter a value"))
b=int(input("enter the another value"))
print(a>b)
print(a<b)
print(a==b)
print(a!=b)
print(a<=b)
print(a>=b)
# Out:
# enter a value2
# enter the another value3
# False
# True
# False
# True
# True
# False

# %%
#this code belongs to assingment operators
c=int(input("enter a value:"))
d=int(input("enter a another value:"))
c+=d
print("\nafter c+=d,c=",c)
c*=d
print("\nafter c*=d,c=",c)
c-=d
print("\nafter c-=d,c=",c)
c/=d
print("\nafter c/=d,c=",c)
c%=d
print("\nafter c%=d,c=",c)
c//=d
print("\nafter c//d,c=",c)
# Out:
# enter a value:2
# enter a another value:4
#
# after c+=d,c= 6
#
# after c*=d,c= 24
#
# after c-=d,c= 20
#
# after c/=d,c= 5.0
#
# after c%=d,c= 1.0
#
# after c//d,c= 0.0

# %%
#this code belongs to logical opertors
s=int(input("Enter a value "))
k=p
k=9
print(s>5 and k>12)
print(s>6 or k<9)
print(not(s>k))
# Out:
# False
# True
# False

# %%
#this code belongs to identity operators
x=int(input("enter a value:"))
y=int(input("enter the value:"))
print(x is y)
print(x is not y)
# Out:
# enter a value:4
# enter the value:5
# False
# True

# %%
#this code belongs to membership operators
x=str(input("enter a value:"))
y=str(input("enter the value:"))
print(x in y)
print(x not in y)
# Out:
# enter a value:keshav
# enter the value:5
# False
# True

# %%
#this code belongs to bitwise operators
x=int(input("enter a value:"))
y=int(input("enter the value:"))
print(x>y & x<y)
print(x>y | x<y)
print(x>y ^ x<y)
# Out:
# enter a value:7
# enter the value:8
# True
# False
# False
